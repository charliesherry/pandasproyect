# %%
import pandas as pd
import numpy as np
import re

# %%
shark_mess = pd.read_csv("data/attacks.csv",encoding="ISO-8859-1")

# %% [markdown]
# ### Comenzamos a eliminar las columnas que no me aportan

# %%
del shark_mess["Unnamed: 22"]

# %%
del shark_mess["Unnamed: 23"]

# %%
del shark_mess["href formula"]

# %%
del shark_mess["pdf"]

# %%
del shark_mess["href"]

# %%
del shark_mess["original order"]

# %%
del shark_mess["Case Number.1"]

# %%
del shark_mess["Case Number.2"]

# %%
del shark_mess["Investigator or Source"]

# %%
del shark_mess["Case Number"]

# %% [markdown]
# ### Luego, quitamos todos los valores NaN de las columnas

# %%
shark_mess = shark_mess.dropna()

# %% [markdown]
# #### Aquí, sustituimos valores para mejor comprensión

# %%
shark_mess["Name"] = shark_mess["Name"].replace("male","NO NAME")

# %%
shark_mess["Name"] = shark_mess["Name"].replace("female","NO NAME")

# %% [markdown]
# ### Reseteamos el índice para poder seguir contando las filas

# %%
shark_mess = shark_mess.reset_index()

# %% [markdown]
# ### Creamos funciones para limpiar el dataset

# %%
def yesser(series):
    return "YES" if series == "Y" else "NO"

# %%
shark_mess["Fatal (Y/N)"]=shark_mess["Fatal (Y/N)"].apply(yesser)

# %% [markdown]
# ### Por último, operaciones de quitar duplicados y de perfeccionar el índice

# %%
shark_mess["Date"] = shark_mess["Date"].drop_duplicates()

# %%
shark_mess = shark_mess.dropna()

# %%
shark_mess.reset_index()
# Out:
#       level_0  index         Date    Year        Type    Country  \
# 0           0      0  25-Jun-2018  2018.0     Boating        USA
# 1           1      6  03-Jun-2018  2018.0  Unprovoked     BRAZIL
# 2           2      8  26-May-2018  2018.0  Unprovoked        USA
# 3           3     10  24-May-2018  2018.0    Provoked  AUSTRALIA
# 4           4     13  13-May-2018  2018.0     Invalid    ENGLAND
# ...       ...    ...          ...     ...         ...        ...
# 1317     1418   5684  02-Mar-1892  1892.0    Provoked  AUSTRALIA
# 1318     1419   5814  25-Nov-1880  1880.0  Unprovoked  AUSTRALIA
# 1319     1420   5922  13-May-1868  1868.0  Unprovoked      INDIA
# 1320     1421   6242        1960s     0.0  Unprovoked       IRAQ
# 1321     1423   6265    1941-1942     0.0  Unprovoked       IRAQ
#
#                  Area                                     Location  \
# 0          California                  Oceanside, San Diego County
# ...

# %%
del shark_mess["index"]

# %%
shark_clean = shark_mess

# %% [markdown]
# ## Este sería el dataset limpio y ordenado según mi hipotesis

# %%
shark_clean
# Out:
#              Date    Year        Type    Country             Area  \
# 0     25-Jun-2018  2018.0     Boating        USA       California
# 1     03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 2     26-May-2018  2018.0  Unprovoked        USA          Florida
# 3     24-May-2018  2018.0    Provoked  AUSTRALIA       Queensland
# 4     13-May-2018  2018.0     Invalid    ENGLAND         Cornwall
# ...           ...     ...         ...        ...              ...
# 1418  02-Mar-1892  1892.0    Provoked  AUSTRALIA  New South Wales
# 1419  25-Nov-1880  1880.0  Unprovoked  AUSTRALIA       Queensland
# 1420  13-May-1868  1868.0  Unprovoked      INDIA     Hoogly River
# 1421        1960s     0.0  Unprovoked       IRAQ           Basrah
# 1423    1941-1942     0.0  Unprovoked       IRAQ           Basrah
#
#                                          Location  \
# 0                     Oceanside, San Diego County
# 1                           Piedade Beach, Recife
# ...

# %% [markdown]
# #### Por ejemplo:

# %%
hipothesis = shark_clean.groupby("Age")["Country"]

# %%
hipothesis.describe()
# Out:
#         count unique           top freq
# Age
#  28         1      1           USA    1
#  30         1      1     AUSTRALIA    1
# 10         19      4           USA   15
# 11          8      3           USA    5
# 12         18      2           USA   15
# ...       ...    ...           ...  ...
# 84          1      1     AUSTRALIA    1
# 9           8      4           USA    5
# 9 or 10     1      1          IRAQ    1
# >50         1      1  SOUTH AFRICA    1
# Teen        1      1           USA    1
#
# [85 rows x 4 columns]
